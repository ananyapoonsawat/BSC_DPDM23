# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyapoonsawat/BSC_DPDM23/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Start

# %%
import numpy as np
import pandas as pd
import os
from google.colab import drive
drive.mount('/content/drive')
shopping_data = pd.read_csv("/content/drive/MyDrive/BSC_DPDM_23/customer_shopping_data.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
shopping_data.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %% [markdown]
# # ข้อมูลบางส่วนมีค่าตัวแปรบางตัวที่ไม่ทราบค่า (Missing Data)

# %% [markdown]
# ตรวจสอบค่าก่อน missing

# %%
shopping_data.isnull().any()
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price             False
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %%
shopping_data.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# ##เราจะลบ price ของ records ที่เป็น cothing,cash,Metrocity เพื่อจะจำลอง missing data

# %% [markdown]
# ทำให้ price เป็น missing

# %%
shopping_new = shopping_data[shopping_data['category']=='Clothing']
shopping_new2=shopping_new[shopping_new['payment_method']=='Cash']
shopping_new3 = shopping_new2[shopping_new2['shopping_mall']=='Metrocity']
shopping_new3
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 382      I591015     C286181  Female   69  Clothing         1   300.08
# 446      I423124     C109593  Female   66  Clothing         1   300.08
# 531      I223795     C280596    Male   40  Clothing         3   900.24
# 647      I891465     C175833  Female   19  Clothing         1   300.08
# ...          ...         ...     ...  ...       ...       ...      ...
# 98987    I693615     C323954  Female   33  Clothing         2   600.16
# 99153    I922072     C336171    Male   47  Clothing         4  1200.32
# 99178    I135939     C211085    Male   40  Clothing         3   900.24
# 99339    I287566     C216529  Female   48  Clothing         1   300.08
# 99390    I283542     C780439    Male   35  Clothing         1   300.08
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# ...

# %%
hasmissing = shopping_data[(shopping_data['category']=='Clothing') &
              (shopping_data['payment_method']=='Cash') &
              (shopping_data['shopping_mall']=='Metrocity')]

# %%
hasmissing['price']= np.nan #ทำให้ค่ากลายเป็น missing
# Out:
# <ipython-input-48-e70a23699fed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hasmissing['price']= np.nan #ทำให้ค่ากลายเป็น missing

# %% [markdown]
# เเยกค่าที่ไม่ทำ missing value

# %%
hasmissing
# Out:
#       invoice_no customer_id  gender  age  category  quantity  price  \
# 2        I127801     C266599    Male   20  Clothing         1    NaN
# 382      I591015     C286181  Female   69  Clothing         1    NaN
# 446      I423124     C109593  Female   66  Clothing         1    NaN
# 531      I223795     C280596    Male   40  Clothing         3    NaN
# 647      I891465     C175833  Female   19  Clothing         1    NaN
# ...          ...         ...     ...  ...       ...       ...    ...
# 98987    I693615     C323954  Female   33  Clothing         2    NaN
# 99153    I922072     C336171    Male   47  Clothing         4    NaN
# 99178    I135939     C211085    Male   40  Clothing         3    NaN
# 99339    I287566     C216529  Female   48  Clothing         1    NaN
# 99390    I283542     C780439    Male   35  Clothing         1    NaN
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# ...

# %%
nonmissing=shopping_data[(shopping_data['category']!='Clothing') |
              (shopping_data['payment_method']!='Cash') |
              (shopping_data['shopping_mall']!='Metrocity')]

# %% [markdown]
# เอาค่ากลับมารวม

# %%
new_shopping_data = pd.concat([hasmissing,nonmissing]).reset_index()
new_shopping_data.shape
# Out:
# (99457, 11)

# %% [markdown]
# ## Example

# %%
new_shopping_data
# Out:
#        index invoice_no customer_id  gender  age         category  quantity  \
# 0          2    I127801     C266599    Male   20         Clothing         1
# 1        382    I591015     C286181  Female   69         Clothing         1
# 2        446    I423124     C109593  Female   66         Clothing         1
# 3        531    I223795     C280596    Male   40         Clothing         3
# 4        647    I891465     C175833  Female   19         Clothing         1
# ...      ...        ...         ...     ...  ...              ...       ...
# 99452  99452    I219422     C441542  Female   45         Souvenir         5
# 99453  99453    I325143     C569580    Male   27  Food & Beverage         2
# 99454  99454    I824010     C103292    Male   63  Food & Beverage         2
# 99455  99455    I702964     C800631    Male   56       Technology         4
# 99456  99456    I232867     C273973  Female   36         Souvenir         3
#
# ...

# %%
new_shopping_data.isnull().any()
# Out:
# index             False
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price              True
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %%
new_shopping_data.describe()
# Out:
#               index           age      quantity         price
# count  99457.000000  99457.000000  99457.000000  97173.000000
# mean   49728.000000     43.427089      3.003429    684.423873
# std    28710.907199     14.990054      1.413025    949.438067
# min        0.000000     18.000000      1.000000      5.230000
# 25%    24864.000000     30.000000      2.000000     40.660000
# 50%    49728.000000     43.000000      3.000000    203.300000
# 75%    74592.000000     56.000000      4.000000   1200.320000
# max    99456.000000     69.000000      5.000000   5250.000000

# %% [markdown]
# ## Fix

# %% [markdown]
# ### 1.ignore (ลบออก)

# %% [markdown]
# ###Quiz
# * data หายไปกี่ %
# * mean data รวมหลังจากเเก้ missing เป็นค่าเท่าไร

# %%
len(new_shopping_data)
# Out:
# 99457

# %%
dropna_data=new_shopping_data.dropna()

# %%
dropna_data
# Out:
#        index invoice_no customer_id  gender  age         category  quantity  \
# 2284       0    I138884     C241288  Female   28         Clothing         5
# 2285       1    I317333     C111565    Male   21            Shoes         3
# 2286       3    I173702     C988172  Female   66            Shoes         5
# 2287       4    I337046     C189076  Female   53            Books         4
# 2288       5    I227836     C657758  Female   28         Clothing         5
# ...      ...        ...         ...     ...  ...              ...       ...
# 99452  99452    I219422     C441542  Female   45         Souvenir         5
# 99453  99453    I325143     C569580    Male   27  Food & Beverage         2
# 99454  99454    I824010     C103292    Male   63  Food & Beverage         2
# 99455  99455    I702964     C800631    Male   56       Technology         4
# 99456  99456    I232867     C273973  Female   36         Souvenir         3
#
# ...

# %%
100*(len(new_shopping_data)-len(dropna_data))/len(new_shopping_data)
# Out:
# 2.2964698311833254

# %%
dropna_data.describe()
# Out:
#               index           age      quantity         price
# count  97173.000000  97173.000000  97173.000000  97173.000000
# mean   49719.605158     43.421671      3.003931    684.423873
# std    28719.460446     14.990459      1.413123    949.438067
# min        0.000000     18.000000      1.000000      5.230000
# 25%    24848.000000     30.000000      2.000000     40.660000
# 50%    49715.000000     43.000000      3.000000    203.300000
# 75%    74596.000000     56.000000      4.000000   1200.320000
# max    99456.000000     69.000000      5.000000   5250.000000

# %% [markdown]
# ### 2.เติมด้วย unknown *เราจะเติมกับข้อมูล categorical

# %% [markdown]
# ### 3. เติมค่าด้วย missing value

# %%
fillna_data = new_shopping_data.fillna(dropna_data['price'].mean())

# %%
fillna_data
# Out:
#        index invoice_no customer_id  gender  age         category  quantity  \
# 0          2    I127801     C266599    Male   20         Clothing         1
# 1        382    I591015     C286181  Female   69         Clothing         1
# 2        446    I423124     C109593  Female   66         Clothing         1
# 3        531    I223795     C280596    Male   40         Clothing         3
# 4        647    I891465     C175833  Female   19         Clothing         1
# ...      ...        ...         ...     ...  ...              ...       ...
# 99452  99452    I219422     C441542  Female   45         Souvenir         5
# 99453  99453    I325143     C569580    Male   27  Food & Beverage         2
# 99454  99454    I824010     C103292    Male   63  Food & Beverage         2
# 99455  99455    I702964     C800631    Male   56       Technology         4
# 99456  99456    I232867     C273973  Female   36         Souvenir         3
#
# ...

# %%
fillna_data.describe()
# Out:
#               index           age      quantity         price
# count  99457.000000  99457.000000  99457.000000  99457.000000
# mean   49728.000000     43.427089      3.003429    684.423873
# std    28710.907199     14.990054      1.413025    938.472859
# min        0.000000     18.000000      1.000000      5.230000
# 25%    24864.000000     30.000000      2.000000     45.450000
# 50%    49728.000000     43.000000      3.000000    203.300000
# 75%    74592.000000     56.000000      4.000000   1200.320000
# max    99456.000000     69.000000      5.000000   5250.000000

# %% [markdown]
# ### 4.fill ด้วยกลุ่ม

# %% [markdown]
# * mean หลังเติมด้วยค่าเฉลี่ย Clothing
# * mean หลังเติมด้วยค่าเฉลี่ย Cash
# * mean หลังเติมด้วยค่าเฉลี่ย Metrocity
# * mean หลังเติมด้วยค่าเฉลี่ย Cash & Metrocity

# %%
C_M =new_shopping_data[(new_shopping_data['payment_method'] == 'Cash') &
                  (new_shopping_data['shopping_mall'] == 'Metrocity')]

# %%
C_M['price'].mean()
# Out:
# 577.9630292559318

# %%
fillna_data3=new_shopping_data.fillna(C_M['price'].mean())

# %%
fillna_data3
# Out:
#        index invoice_no customer_id  gender  age         category  quantity  \
# 0          2    I127801     C266599    Male   20         Clothing         1
# 1        382    I591015     C286181  Female   69         Clothing         1
# 2        446    I423124     C109593  Female   66         Clothing         1
# 3        531    I223795     C280596    Male   40         Clothing         3
# 4        647    I891465     C175833  Female   19         Clothing         1
# ...      ...        ...         ...     ...  ...              ...       ...
# 99452  99452    I219422     C441542  Female   45         Souvenir         5
# 99453  99453    I325143     C569580    Male   27  Food & Beverage         2
# 99454  99454    I824010     C103292    Male   63  Food & Beverage         2
# 99455  99455    I702964     C800631    Male   56       Technology         4
# 99456  99456    I232867     C273973  Female   36         Souvenir         3
#
# ...

# %%
fillna_data3.describe()
# Out:
#               index           age      quantity         price
# count  99457.000000  99457.000000  99457.000000  99457.000000
# mean   49728.000000     43.427089      3.003429    681.979032
# std    28710.907199     14.990054      1.413025    938.608338
# min        0.000000     18.000000      1.000000      5.230000
# 25%    24864.000000     30.000000      2.000000     45.450000
# 50%    49728.000000     43.000000      3.000000    203.300000
# 75%    74592.000000     56.000000      4.000000   1200.320000
# max    99456.000000     69.000000      5.000000   5250.000000

# %% [markdown]
# # ข้อมูลมีความซ้ำซ้อน (Duplicate Data)

# %% [markdown]
# ###สร้าง data Duplicate Data

# %%
willbedup = shopping_data[(shopping_data['category']=='Clothing') &
              (shopping_data['payment_method']=='Cash') &
              (shopping_data['shopping_mall']=='Metrocity')]

# %%
new_shopping_dup = pd.concat([shopping_data,willbedup])

# %%
new_shopping_dup.describe()
# Out:
#                  age       quantity          price
# count  101741.000000  101741.000000  101741.000000
# mean       43.432264       3.002949     693.871800
# std        14.989665       1.412931     933.210127
# min        18.000000       1.000000       5.230000
# 25%        30.000000       2.000000      45.450000
# 50%        43.000000       3.000000     300.080000
# 75%        56.000000       4.000000    1200.320000
# max        69.000000       5.000000    5250.000000

# %%
new_shopping_dup=new_shopping_dup.sort_values(by='invoice_date') #เรียงข้อมูลตามเวลา

# %% [markdown]
# ## Example

# %%
new_shopping_dup[new_shopping_dup.duplicated()] #เช็กว่าข้อมูลไหนซ้ำ
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 30645    I235671     C196703  Female   45  Clothing         2   600.16
# 27812    I836951     C382440    Male   54  Clothing         3   900.24
# 67018    I122424     C970402  Female   30  Clothing         1   300.08
# 52134    I740632     C283467  Female   49  Clothing         5  1500.40
# 32519    I341543     C754279  Female   53  Clothing         5  1500.40
# ...          ...         ...     ...  ...       ...       ...      ...
# 82563    I301995     C734886  Female   67  Clothing         2   600.16
# 63360    I180399     C286433  Female   31  Clothing         3   900.24
# 90298    I422962     C183016  Female   55  Clothing         2   600.16
# 97787    I275007     C259969    Male   61  Clothing         2   600.16
# 86164    I473988     C714996  Female   45  Clothing         4  1200.32
#
#       payment_method invoice_date shopping_mall
# 30645           Cash     1/1/2021     Metrocity
# ...

# %% [markdown]
# ## Fix

# %%
new_shopping_dup.drop_duplicates().duplicated().any()
# Out:
# False

# %% [markdown]
# # ข้อมูลบางตัวในชุดข้อมูลมีลักษณะผิดปกติหรือแตกต่างจากข้อมูลส่วนใหญ่ (Outlier)

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Example

# %%
ret = plt.boxplot(shopping_data['price'])

# %% [markdown]
# ## Fix

# %%
ret = plt.boxplot(shopping_data['price'])

# %%
ret
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7aa6e6240580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7aa6e6240ac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7aa6e62402e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7aa6e6241000>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7aa6e62412a0>],
#  'means': []}

# %%
ret['fliers'][0].get_ydata().shape
# Out:
# (5024,)

# %%
ret['whiskers'][0].get_ydata() #หาเส้นmin เเละ IQR-min
# Out:
# array([45.45,  5.23])

# %%
ret['whiskers'][1].get_ydata() #หาเส้นmax เเละ IQR-max
# Out:
# array([1200.32, 2400.68])

# %%
ret['whiskers'][1].get_ydata()[1]
# Out:
# 2400.68

# %%
no_outline=shopping_data[shopping_data['price'] <= 2400.68]

# %%
 plt.boxplot(no_outline['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7aa6e976c130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7aa6e976c670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7aa6e973be50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7aa6e6243700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7aa6e62118a0>],
#  'means': []}

# %% [markdown]
# # ค่าตัวแปรบางตัวที่ไม่ถูกต้อง (Erroneous Data)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ข้อมูลมีค่าตัวแปรไม่สอดคล้องซึ่งกันและกัน (Inconsistent)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# อื่นๆ

# %% [markdown]
# หาว่ามันอยู่ค่าไหน แก้โดยการแทนค่า

# %%
shopping_data.iloc[55784,'age']='less than 18'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-7c9ecc9d44f6> in <cell line: 1>()
# ----> 1 shopping_data.iloc[55784,'age']='less than 18'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     816
#     817         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818         iloc._setitem_with_indexer(indexer, value, self.name)
#     819
#     820     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1793         if take_split_path:
#    1794             # We have to operate column-wise
# -> 1795             self._setitem_with_indexer_split_path(indexer, value, name)
#    1796         else:
#    1797             self._setitem_single_block(indexer, value, name)
#
# ...

# %%
shopping_data.loc[55784,:]
# Out:
# invoice_no               I210628
# customer_id              C525437
# gender                    Female
# age                           18
# category                   Books
# quantity                       2
# price                       30.3
# payment_method              Cash
# invoice_date          30/09/2022
# shopping_mall     Forum Istanbul
# Name: 55784, dtype: object

# %%
shopping_data[(shopping_data['invoice_no']=='I280590')| (shopping_data['invoice_no']=='I210628')]['age']='less than 18'
# Out:
# <ipython-input-95-68d2850799de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shopping_data[(shopping_data['invoice_no']=='I280590')| (shopping_data['invoice_no']=='I210628')]['age']='less than 18'

# %%
shopping_data[(shopping_data['invoice_no']=='I280590')| (shopping_data['invoice_no']=='I210628')]
# Out:
#       invoice_no customer_id  gender  age  category  quantity   price  \
# 55784    I210628     C525437  Female   18     Books         2   30.30
# 78728    I280590     C142284  Female   18  Clothing         2  600.16
#
#       payment_method invoice_date   shopping_mall
# 55784           Cash   30/09/2022  Forum Istanbul
# 78728     Debit Card   26/10/2022  Forum Istanbul

# %%
shopping_data.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# ###สมมติว่า error บอกว่าไม่สามารถประมวลค่า 'less than 18' ได้

# %% [markdown]
# ###ทดลองทำให้error

# %%
shopping_data[shopping_data.eq('less than 18').any(1)]
# Out:
# <ipython-input-94-4744250e9fad>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   shopping_data[shopping_data.eq('less than 18').any(1)]
# Empty DataFrame
# Columns: [invoice_no, customer_id, gender, age, category, quantity, price, payment_method, invoice_date, shopping_mall]
# Index: []

# %% [markdown]
# ###แทนค่า ด้วยค่าที่เหมาะสม

# %%
shopping_data['age'] = shopping_data['age'].replace('less than 18',17)

# %%
shopping_data[(shopping_data['invoice_no']=='I280590')| (shopping_data['invoice_no']=='I210628')]
# Out:
#       invoice_no customer_id  gender  age  category  quantity   price  \
# 55784    I210628     C525437  Female   18     Books         2   30.30
# 78728    I280590     C142284  Female   18  Clothing         2  600.16
#
#       payment_method invoice_date   shopping_mall
# 55784           Cash   30/09/2022  Forum Istanbul
# 78728     Debit Card   26/10/2022  Forum Istanbul

# %% [markdown]
# ## Example
#
# เกิดเมื่อรวมข้อมูลจากหลยแหล่งแล้ว ค่าใน 2 columns ไม่เป็นไปในทางเดียวกันเช่น column อายุไม่ตรงกัน column วันเกิดหลังจากคำนวณอายุแล้ว
#
# เลือกเก็บไว้เฉพาะ column ที่ถูก

# %% [markdown]
# ## Data Integration (การรวมข้อมูลจากหลายแหล่ง)
# ### 1. รวมแกน x (เพิ่ม columns - เพิ่ม feature)

# %%
sep_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/sep65.xlsx',header=8,skipfooter=26) #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
sep_df = sep_df.iloc[-2:,:15]
sep_df['เดือน-ปี']=len(sep_df)*['sep-65']
sep_df
# Out:
#   รายการ      งบประมาณ  สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     7.925745e+07  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09     2.683430e+08  1.119320e+09  8.201965e+09
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         99.375405           98.0      1.375405              1.895253e+10
# 3         85.390363           75.0     10.390363              9.589628e+09
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q4.1  */- เป้าหมาย.1  \
# 2          100.171242            100.0        0.171242
# 3           99.837275            100.0       -0.162725
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2            -3.239918e+07            NaN             NaN   sep-65
# 3             1.563013e+07            6.0            15.0   sep-65

# %%
oct_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/oct65.xlsx',header=9,skipfooter=27) #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
oct_df = oct_df.iloc[-2:,:15]
oct_df['เดือน-ปี']=len(oct_df)*['oct_65']
oct_df
# Out:
#   รายการ     งบประมาณ  สำรองเงินมีหนี้          PO     เบิกจ่าย  \
# 2  ประจำ  6822.811789              NaN   12.706842  3984.779058
# 3  ลงทุน  6180.211723              NaN  457.295806  1291.209026
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q1  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         58.403766           35.0     23.403766               3997.485900
# 3         20.892634           19.0      1.892634               1748.504832
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q1.1  */- เป้าหมาย.1  \
# 2           58.590007            35.33       23.260007
# 3           28.291989            28.96       -0.668011
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2              2825.325889            NaN             NaN   oct_65
# 3              4431.706890            4.0             6.0   oct_65

# %%
sep_oct_df = pd.concat([sep_df,oct_df])
sep_oct_df #รวมแนวแกน y
# Out:
#   รายการ      งบประมาณ  สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     7.925745e+07  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09     2.683430e+08  1.119320e+09  8.201965e+09
# 2  ประจำ  6.822812e+03              NaN  1.270684e+01  3.984779e+03
# 3  ลงทุน  6.180212e+03              NaN  4.572958e+02  1.291209e+03
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         99.375405           98.0      1.375405              1.895253e+10
# 3         85.390363           75.0     10.390363              9.589628e+09
# 2         58.403766            NaN     23.403766              3.997486e+03
# 3         20.892634            NaN      1.892634              1.748505e+03
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q4.1  */- เป้าหมาย.1  \
# 2          100.171242            100.0        0.171242
# 3           99.837275            100.0       -0.162725
# 2           58.590007              NaN       23.260007
# ...

# %% [markdown]
# ### 2. รวมแกน Y (เพิ่ม rows - เพิ่ม data)

# %%
project_df = pd.read_csv('/content/drive/MyDrive/DataViz23Data/opendata_project-2.csv') #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
project_df
# Out:
#        row_number                project_id                     name_en  \
# 0         20809.0  5ec3409884c1860019f3298d    Baan Laksiri Surin-Korco
# 1          4268.0             project_15905              Liberty Park 2
# 2          5849.0  62b2b082cb0d2c0014be01a6  Pleno Paholyothin-Saimai 2
# 3         21762.0              project_6010              Baan Thara Rin
# 4         10751.0             project_11312             The Forest Hill
# ...           ...                       ...                         ...
# 23862     17534.0              project_9330   Parinyada Wongwan Sathorn
# 23863     12360.0              project_9316              Sinwong Garden
# 23864      6865.0             project_15993      La Maison Sukhumvit 22
# 23865        74.0               project_105                    Regent 1
# 23866     20538.0  5f2bcbd0306e7e0019068db0     Baanruenrom Nongphueng
#
#                           name_th propertytype_id propertytype_name_en  \
# ...

# %%
unit_df = pd.read_csv('/content/drive/MyDrive/DataViz23Data/opendata_unittype-2.csv') #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
unit_df
# Out:
#        row_number               unittype_id                project_id  \
# 0           37586            unittype_35602             project_15270
# 1            9427             unittype_4487              project_1476
# 2           12994            unittype_37624             project_16674
# 3           19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4           10907             unittype_8344              project_2821
# ...           ...                       ...                       ...
# 43369        9507             unittype_5086              project_1635
# 43370       23721            unittype_15644              project_6109
# 43371       31551            unittype_21385              project_8392
# 43372       29837            unittype_26243             project_10566
# 43373        9465            unittype_35686             project_15298
#
#                           name_th  propertytype_id propertytype_name_en  \
# ...

# %%
### ไม่เอามั้ง
project_df = project_df.drop_duplicates(subset='project_id')
unit_df['province_en'] = unit_df['project_id'].map(project_df.set_index('project_id')['province_name_en'])

# %%
project_df[project_df.duplicated()]
# Out:
#        row_number project_id name_en        name_th propertytype_id  \
# 5610          NaN  ขนส่งปทุม    3611      BAN CHANG         บ้านฉาง
# 10204         NaN  ขนส่งปทุม    3656  BANG PHO NUEA   บางโพธิ์เหนือ
#
#       propertytype_name_en propertytype_name_th      price_min developer_id  \
# 5610                  3600  MUEANG PATHUM THANI  เมืองปทุมธานี         3599
# 10204                 3647             SAM KHOK         สามโคก         3599
#
#       developer_name_en  ... facility_park  facility_playground  \
# 5610       Pathum Thani  ...           NaN                  NaN
# 10204      Pathum Thani  ...           NaN                  NaN
#
#        facility_pool facility_security date_created date_finish  date_updated  \
# 5610             NaN               NaN          NaN         NaN           NaN
# 10204            NaN               NaN          NaN         NaN           NaN
#
#       source url_project  day
# 5610     NaN         NaN  NaN
# 10204    NaN         NaN  NaN
#
# ...

# %%
project_df = project_df.drop_duplicates(subset='project_id',keep='last')

# %%
unit_df['province_en'] = unit_df['project_id'].map(project_df.set_index('project_id')['province_name_en'])
unit_df
# Out:
#        row_number               unittype_id                project_id  \
# 0           37586            unittype_35602             project_15270
# 1            9427             unittype_4487              project_1476
# 2           12994            unittype_37624             project_16674
# 3           19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4           10907             unittype_8344              project_2821
# ...           ...                       ...                       ...
# 43369        9507             unittype_5086              project_1635
# 43370       23721            unittype_15644              project_6109
# 43371       31551            unittype_21385              project_8392
# 43372       29837            unittype_26243             project_10566
# 43373        9465            unittype_35686             project_15298
#
#                           name_th  propertytype_id propertytype_name_en  \
# ...

# %% [markdown]
# ##Data Reduction
# ###Reduce number of data (Y-axis) - Sampling
# ###Reduce number of data (X-axis) - PCA & State

# %%
shopping_data.sample(n=10,random_state=6)
# Out:
#       invoice_no customer_id  gender  age         category  quantity   price  \
# 81034    I209459     C312307  Female   18         Souvenir         1   11.73
# 91838    I351059     C292856    Male   41         Clothing         2  600.16
# 20458    I323617     C325754  Female   24         Clothing         2  600.16
# 73343    I104653     C209092    Male   62             Toys         5  179.20
# 70406    I804767     C196027  Female   65         Clothing         3  900.24
# 65247    I137393     C726791  Female   37  Food & Beverage         3   15.69
# 49419    I650563     C283975    Male   28         Clothing         3  900.24
# 90371    I109001     C901685  Female   36             Toys         3  107.52
# 98492    I394097     C307872    Male   29  Food & Beverage         1    5.23
# 11309    I163506     C223150    Male   34  Food & Beverage         1    5.23
#
#       payment_method invoice_date     shopping_mall
# 81034           Cash   13/05/2021       Cevahir AVM
# ...

# %%
sam_no_replace = shopping_data.sample(frac=0.2,random_state=6)
sam_no_replace.duplicated().any()
# Out:
# False

# %%
sam_with_replace = shopping_data.sample(frac=0.2, replace=True, random_state=6)
sam_with_replace.duplicated().any()
# Out:
# True

# %%
sam_with_replace_120 = shopping_data.sample(frac=1.2, replace=True, random_state=6)
sam_with_replace_120.shape
# Out:
# (119348, 10)
