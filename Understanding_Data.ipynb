# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyapoonsawat/BSC_DPDM23/blob/main/Understanding_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load data

# %%
import pandas as pd

# %% [markdown]
# ## Load Excel from Gdrive

# %%
#mounting colab with google drive
#mount =  เชื่อมไดร์ฟ
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_from_gdrive = pd.read_excel('/content/drive/MyDrive/BSC_DPDM_23/BSC_dpdm23_data/2563.xls',header=2)

# %%
data_from_gdrive
# Out:
#      Unnamed: 0          Unnamed: 1                               Unnamed: 2  \
# 0           NaN                 NaN                                      NaN
# 1    เลขที่คำขอ  เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย
# 2        610707    62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 3        620660    63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# 4        610182    63-0101-1-00-1-0                        อาร์ต ออฟ เบคกิ้ง
# ..          ...                 ...                                      ...
# 657     E630369    63-0669-1-00-0-0  อีเลคโทรลักซ์ โปรเฟสชั่นแนล (ประเทศไทย)
# 658     E630401    63-0682-1-00-1-0                            โกลว์ พลังงาน
# 659     E630277    63-0666-1-03-1-0         ยูนิค อุตสาหกรรมพลาสติก (แม่สอด)
# 660      610552    63-0676-1-00-1-0                   ไอชิน เอไอ (ประเทศไทย)
# 661     E630269    63-0668-1-00-1-0     เอ็มเอ็มซี อีเล็คโทรนิคส์ (ไทยแลนด์)
#
# ...

# %% [markdown]
# ## Load Excel from Gsheet

# %%
from google.colab import auth
auth.authenticate_user

#ใช้sheetได้ทั้งหมด
import gspread
from google.auth import default
creds, _= default()

#เลือกsheetของเรา
gc = gspread.authorize(creds)

# %%
gsht = gc.open_by_key('1OjI9h_6RipL3M_OjFXiF4q6owUBQtd3D7-TuJV3G62E')

# %%
worksheet2 = gsht.worksheet("มิ.ย. 2563")
rows = worksheet2.get_all_values()
data_from_gsheets = pd.DataFrame.from_records(rows)
# Out:
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py in refresh(self, request)
#     110         try:
# --> 111             self._retrieve_info(request)
#     112             self.token, self.expiry = _metadata.get_service_account_token(
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py in _retrieve_info(self, request)
#      86         """
# ---> 87         info = _metadata.get_service_account_info(
#      88             request, service_account=self._service_account_email
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py in get_service_account_info(request, service_account)
#     233     # for more on the use of 'recursive'.
# --> 234     return get(request, path, params={"recursive": "true"})
#     235
#
# ...

# %%
data_from_gsheets.columns=data_from_gsheets.iloc[2]
data_from_gsheet=data_from_gsheets.iloc[3:].reset_index().ilo[:,1:]
data_from_gsheet.head()

# %% [markdown]
# ##Load CSV

# %%
#mounting colab with google drive
#mount =  เชื่อมไดร์ฟ
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
shopping_data = pd.read_csv('/content/drive/MyDrive/BSC_DPDM_23/BSC_dpdm23_data/shopping.csv-20231129T020732Z-001.zip')

# %%
shoppingC_data = pd.read_csv('/content/drive/MyDrive/BSC_DPDM_23/BSC_dpdm23_data/customer_shopping_data.csv-20231129T024356Z-001.zip')

# %%
shoppingC_data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
shoppingC_data.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %% [markdown]
# #####How many payment methds?

# %%
shopping_data['Payment Method'].unique()
# Out:
# array(['Venmo', 'Cash', 'Credit Card', 'PayPal', 'Bank Transfer',
#        'Debit Card'], dtype=object)

# %%
set(shopping_data['Payment Method'])
# Out:
# {'Bank Transfer', 'Cash', 'Credit Card', 'Debit Card', 'PayPal', 'Venmo'}

# %%
shopping_data.value_counts('Payment Method')
# Out:
# Payment Method
# PayPal           677
# Credit Card      671
# Cash             670
# Debit Card       636
# Venmo            634
# Bank Transfer    612
# dtype: int64

# %%
shoppingC_data.groupby('Payment Method').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-96fcf42685aa> in <cell line: 1>()
# ----> 1 shoppingC_data.groupby('Payment Method').count()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     963             from pandas.core.groupby.grouper import get_grouper
#     964
# --> 965             grouper, exclusions, obj = get_grouper(
#     966                 obj,
# ...

# %% [markdown]
# ######ลูกค้าที่อายุมากกว่า 40 ปี มีค่าเฉลี่ย 	Purchase Amount (USD) เท่าไหร่

# %%
shopping_data[shopping_data['Age']>40].mean()
# Out:
# <ipython-input-18-a42cdc3ecb6a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   shopping_data[shopping_data['Age']>40].mean()
# Customer ID              1954.827942
# Age                        55.384097
# Purchase Amount (USD)      59.572776
# Review Rating               3.731851
# Previous Purchases         25.689128
# dtype: float64

# %% [markdown]
# #Basic stats

# %%
from matplotlib import pyplot as plt

# %%
histoutput=pm

# %%
plt.hist(shoppingC_data['shopping_mall'])
plt.xticks(rotation='vertical');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-03bb61ecfece> in <cell line: 1>()
# ----> 1 hihtoutplt.hist(shoppingC_data['shopping_mall'])
#       2 plt.xticks(rotation='vertical');
#
# NameError: name 'hihtoutplt' is not defined

# %%
shopping_data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
data_from_gsheets.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-a986d53e78fc> in <cell line: 1>()
# ----> 1 data_from_gsheets.describe()
#
# NameError: name 'data_from_gsheets' is not defined

# %% [markdown]
# #Visualization

# %% [markdown]
# #Distance-Similarity

# %%
from numpy import linalg as LA

# %%
import numpy as np

# %%
import pandas as pd
from scipy.spatial import distance_matrix

# %%
data_points = np.array({ [1,2], [-1,4], [0,-3], [-3,-2] })

# %%
data_points

# %%
plt.scatter(data_points[:,0],data_points[:,0])

# %%
LA.norm(data_points,ord=2,axis=1)

# %%
distance_matrix[data_points,data_points]

# %%
plt.scatter(data_points(:,0)..........) แก้missing outliner ค่าที่ไม่ตรง

# %% [markdown]
# #z-score
