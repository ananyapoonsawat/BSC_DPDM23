# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyapoonsawat/BSC_DPDM23/blob/main/%E0%B8%97%E0%B8%94%E0%B8%AA%E0%B8%AD%E0%B8%9Aing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #นำเข้าข้อมูล

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive') # mount =  เชื่อมไดร์ฟ
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel('/content/drive/MyDrive/ทดสอบ.xlsx') #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
data
# Out:
#       sequence      id  identification       sday            idp  \
# 0            1  112564    5.401000e+12 2018-10-18  1409904001761
# 1            3  115409    3.409700e+12 2018-10-18  1409903664278
# 2            5  115640    1.539900e+12 2018-10-18  1409904269224
# 3            7  109387    3.300101e+12 2018-10-18  1309903039251
# 4            9  113118    3.439900e+12 2018-10-18  1409904112732
# ...        ...     ...             ...        ...            ...
# 4439      8839  118720             NaN 2023-04-26  1479901161660
# 4440      8841  118720             NaN 2023-04-26  1479901250484
# 4441      8843  124281             NaN 2023-06-22  1409904769481
# 4442      8845  132129             NaN 2024-01-10  1529902713720
# 4443      8847  132129             NaN 2023-12-08  1409904827995
#
#                                name  \
# 0            เด็กหญิงจิตติมา  สุดใด
# 1        เด็กชายกันตพัฒน์  พิมพ์แมน
# 2         เด็กหญิงพรรณปพร  แถลงธรรม
# ...

# %%
data['name'].str.startswith('เด็กหญิง')
#ลองเช็คข้อมูล
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 4439    False
# 4440    False
# 4441    False
# 4442    False
# 4443    False
# Name: name, Length: 4444, dtype: object

# %% [markdown]
# #เปลี่ยนข้อมูล name columns

# %%
data['name'] = data['name'].str.replace('เด็กชาย','ด.ช.')
data['name'] = data['name'].str.replace('เด็กหญิง','ด.ญ.')

data['name'] = data['name'].str.replace('ดช.','ด.ช.')
data['name'] = data['name'].str.replace('ดญ.','ด.ญ.')

data['name'] = data['name'].str.replace('ด.ช. ','ด.ช.')
data['name'] = data['name'].str.replace('ด.ญ. ','ด.ญ.')

data['name'] = data['name'].str.replace('ดช. ','ด.ช.')
data['name'] = data['name'].str.replace('ดญ. ','ด.ญ.')

# %%
list(data['name']) = data['name'].str.startswith('เด็กหญิง','เด็กชาย')
#ลองเช็คข้อมูล
# Out:
#   File "<ipython-input-60-b938a1c7f122>", line 1
#     list(data['name']) = data['name'].str.startswith('เด็กหญิง','เด็กชาย')
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
