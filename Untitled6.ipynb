# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyapoonsawat/BSC_DPDM23/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Quiz 9

# %% [markdown]
# ###Grounnd talk

# %% [markdown]
# ![427756240_1146834570012112_4581794703168329006_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ###Accuracy![427673761_1592794598142425_5134747019683814273_n.jpg](data:image/jpeg;base64,...)
