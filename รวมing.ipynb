# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyapoonsawat/BSC_DPDM23/blob/main/%E0%B8%A3%E0%B8%A7%E0%B8%A1ing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive') # mount =  เชื่อมไดร์ฟ
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #ประวัติการให้ทุนการศึกษาบุตรบุคลากร

# %% [markdown]
# ##นำเข้าข้อมูล ประวัติการให้ทุนการศึกษาบุตรบุคลากร

# %%
data = pd.read_excel('/content/drive/MyDrive/ทุนบุตร.xlsx') #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-47e10557d8b8> in <cell line: 1>()
# ----> 1 data = pd.read_excel('/content/drive/MyDrive/ทุนบุตร.xlsx') #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
#     480         raise ValueError(
#
# ...

# %%
aa = data['name'].str.startswith('ด.ช.','ด.ญ.')
#ลองเช็คข้อมูล
aa
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 4439    False
# 4440    False
# 4441    False
# 4442    False
# 4443    False
# Name: name, Length: 4444, dtype: object

# %% [markdown]
# ##เปลี่ยนข้อมูลคอลัมล์ columns ประวัติการให้ทุนการศึกษาบุตรบุคลากร

# %%
data['name'] = data['name'].str.replace('เด็ฏชาย','ด.ช.')
data['name'] = data['name'].str.replace('เด็กชาย','ด.ช.')
data['name'] = data['name'].str.replace('เด็กหญฺง ','ด.ญ.')
data['name'] = data['name'].str.replace('เด้กหญิง','ด.ญ.')
data['name'] = data['name'].str.replace('เด็กหญิง','ด.ญ.')

data['name'] = data['name'].str.replace('ดช.','ด.ช.')
data['name'] = data['name'].str.replace('ดญ.','ด.ญ.')

data['name'] = data['name'].str.replace('ด.ช. ','ด.ช.')
data['name'] = data['name'].str.replace('ด.ญ. ','ด.ญ.')

data['name'] = data['name'].str.replace('ดช. ','ด.ช.')
data['name'] = data['name'].str.replace('ดญ. ','ด.ญ.')

data['name'] = data['name'].str.replace('นาย ','นาย')

data['name'] = data['name'].str.replace('นาง ','นาง')

data['name'] = data['name'].str.replace('นางสาว','น.ส.')
data['name'] = data['name'].str.replace('นางสาว ','น.ส.')
data['name'] = data['name'].str.replace('นางสาง','น.ส.')

data['name'] = data['name'].str.replace('น.ส. ','น.ส.')
data['name'] = data['name'].str.replace('นส.','น.ส.')

data['name']
# Out:
# 0                   ด.ญ.จิตติมา  สุดใด
# 1              ด.ช.กันตพัฒน์  พิมพ์แมน
# 2                ด.ญ.พรรณปพร  แถลงธรรม
# 3              นายคงตระกูล  หรั่งยี่โถ
# 4            ด.ญ.กิตรดา  เวทีวุฒาจารย์
#                      ...
# 4439            ด.ญ.เพลงณหทัย ภูศรีโสม
# 4440             ด.ญ.พราวณกมล ภูศรีโสม
# 4441    ด.ญ.เอวารินทร์ อินทร์ประสิทธิ์
# 4442                 ด.ญ.พรประภา ใจลึก
# 4443                   ด.ญ.พีรดา ใจลึก
# Name: name, Length: 4444, dtype: object

# %%
data
# Out:
#       sequence      id  identification       sday            idp  \
# 0            1  112564    5.401000e+12 2018-10-18  1409904001761
# 1            3  115409    3.409700e+12 2018-10-18  1409903664278
# 2            5  115640    1.539900e+12 2018-10-18  1409904269224
# 3            7  109387    3.300101e+12 2018-10-18  1309903039251
# 4            9  113118    3.439900e+12 2018-10-18  1409904112732
# ...        ...     ...             ...        ...            ...
# 4439      8839  118720             NaN 2023-04-26  1479901161660
# 4440      8841  118720             NaN 2023-04-26  1479901250484
# 4441      8843  124281             NaN 2023-06-22  1409904769481
# 4442      8845  132129             NaN 2024-01-10  1529902713720
# 4443      8847  132129             NaN 2023-12-08  1409904827995
#
#                                 name  \
# 0                 ด.ญ.จิตติมา  สุดใด
# 1            ด.ช.กันตพัฒน์  พิมพ์แมน
# 2              ด.ญ.พรรณปพร  แถลงธรรม
# ...

# %% [markdown]
# ##Save ข้อมูล ประวัติการให้ทุนการศึกษาบุตรบุคลากร

# %%
pip install openpyxl

# %%
df = pd.DataFrame(data)

# บันทึก DataFrame เป็นไฟล์ Excel
df.to_excel('ประวัติการให้ทุนการศึกษาบุตรบุคลากร(python).xlsx', index=False)
#Downlaod ไฟล์

# %% [markdown]
# #ประวัติการรับทุนของบุคลากร

# %% [markdown]
# ##นำเข้าข้อมูล ประวัติการรับทุนของบุคลากร

# %%
dv = pd.read_excel('/content/drive/MyDrive/ข้อมูล กองทรัพย์/ประวัติการรับทุนของบุคลากร.xlsx') #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
dv
# Out:
#      seq      id   startday    stopday  \
# 0      1  109776 2001-06-01 2007-05-30
# 1      2  109375 2001-06-01 2002-05-29
# 2      3  102978 2001-06-01 2006-04-10
# 3      4  109775 2001-06-01 2003-08-19
# 4      5  109991 2001-06-01 2004-04-02
# ..   ...     ...        ...        ...
# 473  521  119707 2023-03-01        NaT
# 474  523  118782 2023-07-03        NaT
# 475  525  128187 2024-06-01        NaT
# 476  527  128447 2024-03-04 2027-03-03
# 477  529  125707 2023-09-30 2026-09-29
#
#                                                   name    rname      level  \
# 0                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์  ปริญญาเอก
# 1                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์   ปริญญาโท
# 2                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์  ปริญญาเอก
# 3                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์  ปริญญาเอก
# 4                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์   ปริญญาโท
# ...

# %% [markdown]
# ##เปลี่ยนข้อมูลคอลัมล์ columns ประวัติการรับทุนของบุคลากร

# %%
dv['course'] = dv['course'].str.replace('ปริญญาเอกร่วมกับมหาวิยาลัยในต่างประเทศ','ปริญญาเอกร่วมกับมหาวิทยาลัยในต่างประเทศ')
dv['course'] = dv['course'].str.replace('ปริญญาเอกร่วมร่วมกับมหาวิทยาลัยในต่างประเทศ','ปริญญาเอกร่วมกับมหาวิทยาลัยในต่างประเทศ')

# %%
dv['major'] = dv['major'].str.replace('Nursitng','Nursing')
dv['major'] = dv['major'].str.replace('Romete Sensing & GIS','Remote Sensing & GIS')
dv['major'] = dv['major'].str.replace('Remote Sensing and GIS','Remote Sensing & GIS')
dv['major'] = dv['major'].str.replace('เทคโนโลยีการอาหาร','เทคโนโลยีทางอาหาร')
dv['major'] = dv['major'].str.replace('เทคโนโลยีอาหาร','เทคโนโลยีทางอาหาร')

# %%
dv['place'] = dv['place'].str.replace('Linclon University','Lincoln University')
dv['place'] = dv['place'].str.replace('มหาวิทยาลัยศรีนครินทร์วิโรฒ','มหาวิทยาลัยศรีนครินทรวิโรฒ')
dv['place'] = dv['place'].str.replace('มหาวิทยาลัยเกตษรศาสตร์','มหาวิทยาลัยเกษตรศาสตร์')
dv['place'] = dv['place'].str.replace('คณะแพทยศาสตร์ ม.ขอนแก่น','คณะแพทยศาสตร์ มหาวิทยาลัยขอนแก่น')
dv['place'] = dv['place'].str.replace('มหาวิทยาลัยขอนแกน','มหาวิทยาลัยขอนแก่น')
dv['place'] = dv['place'].str.replace('คณะพยาบาลศาสตร์ ม.ขอนแก่น','คณะพยาบาลศาสตร์ มหาวิทยาลัยขอนแก่น')
dv['place'] = dv['place'].str.replace('คณะแพทยศาสตร์ ม.มหิดล','คณะแพทยศาสตร์ มหาวิทยาลัยมหิดล')
dv['place'] = dv['place'].str.replace('มหาหาวิทยาลัยขอนแก่น','มหาวิทยาลัยขอนแก่น')
dv['place'] = dv['place'].str.replace('มหาวิทยาัยขอนแก่น','มหาวิทยาลัยขอนแก่น')
dv['place'] = dv['place'].str.replace('สถาบันบัณฑิตพัฒนาบริหารศาสตร์','สถาบันบัณฑิตพัฒนบริหารศาสตร์')
dv['place'] = dv['place'].str.replace('รพ.จุฬาลงกรณ์','โรงพยาบาลจุฬาลงกรณ์')
dv['place'] = dv['place'].str.replace('สถาบันเทคโนโลยีพระจอมเกล้าลาดกระบัง','สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง')

# %%
dv['country'] = dv['country'].str.replace('ไทบ','ไทย')
dv['country'] = dv['country'].str.replace('เยอรมัน','เยอรมนี')
dv['country'] = dv['country'].str.replace('สหหรัฐอเมริกา','สหรัฐอเมริกา')

# %% [markdown]
# ##แสดงตาราง dv

# %%
dv
# Out:
#      seq      id   startday    stopday  \
# 0      1  109776 2001-06-01 2007-05-30
# 1      2  109375 2001-06-01 2002-05-29
# 2      3  102978 2001-06-01 2006-04-10
# 3      4  109775 2001-06-01 2003-08-19
# 4      5  109991 2001-06-01 2004-04-02
# ..   ...     ...        ...        ...
# 473  521  119707 2023-03-01        NaT
# 474  523  118782 2023-07-03        NaT
# 475  525  128187 2024-06-01        NaT
# 476  527  128447 2024-03-04 2027-03-03
# 477  529  125707 2023-09-30 2026-09-29
#
#                                                   name    rname      level  \
# 0                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์  ปริญญาเอก
# 1                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์   ปริญญาโท
# 2                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์  ปริญญาเอก
# 3                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์  ปริญญาเอก
# 4                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์   ปริญญาโท
# ...

# %% [markdown]
# ##Save ข้อมูล ประวัติการรับทุนของบุคลากร

# %%
#install pack pip install openpyxl
dv1 = pd.DataFrame(dv)
# บันทึก DataFrame เป็นไฟล์ Excel
dv1.to_excel('ประวัติการรับทุนของบุคลากร(python).xlsx', index=False)
#Downlaod ไฟล์

# %% [markdown]
# #เพิ่มเติม

# %%
dvv = pd.read_excel('/content/drive/MyDrive/ข้อมูล กองทรัพย์/ประวัติการรับทุนของบุคลากร(python).xlsx') #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
dvv
# Out:
#      seq      id   startday    stopday  \
# 0      1  109776 2001-06-01 2007-05-30
# 1      2  109375 2001-06-01 2002-05-29
# 2      3  102978 2001-06-01 2006-04-10
# 3      4  109775 2001-06-01 2003-08-19
# 4      5  109991 2001-06-01 2004-04-02
# ..   ...     ...        ...        ...
# 473  521  119707 2023-03-01        NaT
# 474  523  118782 2023-07-03        NaT
# 475  525  128187 2024-06-01        NaT
# 476  527  128447 2024-03-04 2027-03-03
# 477  529  125707 2023-09-30 2026-09-29
#
#                                                   name    rname      level  \
# 0                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์  ปริญญาเอก
# 1                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์   ปริญญาโท
# 2                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์  ปริญญาเอก
# 3                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์  ปริญญาเอก
# 4                       โครงการพัฒนาอาจารย์สาขาขาดแคลน  อาจารย์   ปริญญาโท
# ...

# %%
dvv1 = dvv[['place']]
dvv1
# Out:
#                                    place
# 0                  จุฬาลงกรณ์มหาวิทยาลัย
# 1                  จุฬาลงกรณ์มหาวิทยาลัย
# 2                       มหาวิทยาลัยมหิดล
# 3                     มหาวิทยาลัยขอนแก่น
# 4                       มหาวิทยาลัยมหิดล
# ..                                   ...
# 473                    Massey University
# 474                มหาวิทยาลัยธรรมศาสตร์
# 475                   มหาวิทยาลัยขอนแก่น
# 476                    Yonsei University
# 477  Queensland University of Technology
#
# [478 rows x 1 columns]

# %%
import numpy as np

# %%
set(dvv1['place'])
# Out:
# {'Asian Institute of Technology  ',
#  'Asian Institute of Technology (AIT)',
#  'Bournemouth University',
#  'Brunel University',
#  'Cardiff University',
#  'Deakin University',
#  'Flinders University',
#  'Flinders University of South Australia',
#  'Florida Athantic University',
#  'Freie Universitat Berlin',
#  'Geneva School of Diplomacy and International Relations',
#  'Griffith University',
#  'Heidelberg University ',
#  'Heriot-Watt University',
#  'International Christian University',
#  'Lincoln University',
#  'Massey University',
#  'Medical College of Wisconsin',
#  'Monash University',
#  'National Taiwan University of Science and Technology',
#  'National Tsing Hua University',
#  'Okayama University',
#  'Portland State University',
#  'Queensland University of Technology',
#  'RMIT University',
#  'Saint Louis University',
#  'Saint Louis University of Tours',
#  'The AO Research Institute Davos',
#  'The University of Manchester',
# ...

# %% [markdown]
# #ทะเบียนกองทุน กฌมข-25042024

# %%
Tun = pd.read_excel('/content/drive/MyDrive/ข้อมูล กองทรัพย์/ผู็รับประโยชน์ คอลลัมล์จากสมุดงาน1.xlsx') #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
#คอลัมล์ผู้รับประโยชน์

# %%
tt = pd.DataFrame(Tun)
tt
# Out:
#               ผู้รับผลประโยชน์
# 0          นายปรามาณ มุสิกโปดก
# 1        นายนนทวุฒิ  นวลโคกสูง
# 2              นางกุศล รักญาติ
# 3        นางเรืองศรี  ทรงปัญญา
# 4     นายสกุลโกสินทร์ ศรีรักษา
# ...                        ...
# 5620     นางอาริยา มูลตรีภักดี
# 5621          ด.ช.นนทวัช คงไทย
# 5622         นางนิตยา ดอนอิสวน
# 5623          นางน้ำอ้อม ยาหอม
# 5624     นางสาวศิรัญญา วรพันธ์
#
# [5625 rows x 1 columns]

# %% [markdown]
# ##เปลี่ยนคอลัมล์ผู้รับผลประโยชน์

# %%
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (ภรรยา)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(ภรรยา)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (สามี)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(สามี)','')

# %%
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (มารดา)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(มารดา)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (บุตร)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(บุตร)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (น้องสาว)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(น้องสาว)','')

# %%
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (บิดา)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(บิดา)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (พี่สาว)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(พี่สาว)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (บุตรชาย)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(บุตรชาย)','')

# %%
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (หลานชาย)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(หลานชาย)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (น้องชาย)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(น้องชาย)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace(' (หลาน)','')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('(หลาน)','')

# %%
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('นย','นาย')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('น.ส.','นางสาว')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('นส.','นางสาว')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ด.ช.','เด็กชาย')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ดช.','เด็กชาย')

# %%
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ด.ญ.','เด็กหญิง')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ด.ญ','เด็กหญิง')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ดญ.','เด็กหญิง')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ดย','เด็กหญิง')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พ.ต.อ.','พันตำรวจเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พตอ.','พันตำรวจเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พ.ต.ท.','พันตำรวจโท')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พ.ต.ท ','พันตำรวจโท')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('รต.','ร้อยตรี')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ร.ต.','ร้อยตรี')

# %%
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ดต. ','ดาบตำรวจ')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ดต.','ดาบตำรวจ')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ด.ต.','ดาบตำรวจ')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('จสอ.','จ่าสิบเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('จ.ส.อ.','จ่าสิบเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('จ.ส.อ','จ่าสิบเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ส.ต.ต.','สิบตำรวจตรี')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ส.ต.ท.','สิบตำรวจโท')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ส.ต.อ.','สิบตำรวจเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ส.อ.','สิบเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('สอ.','สิบเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('จอ.','จ่าเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พ.อ.อ.','พันจ่าอากาศเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ว่าที่ร.ต.','ว่าที่ร้อยตรี')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ว่าที่ รต.','ว่าที่ร้อยตรี')

# %%
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ร.ต.ท.','ร้อยตำรวจโท')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('รต.ท.','ร้อยตำรวจโท')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ร.ตท.','ร้อยตำรวจโท')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('นพ.','นายแพทย์')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('จสต.','จ่าสิบตำรวจ')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('จ.ส.ต.','จ่าสิบตำรวจ')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ร.ต.อ.','ร้อยตำรวจเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พ.จ.อ.','พันจ่าเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พล.ต.ท.','พลตำรวจโท')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พ.ต.','พันตรี')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พต.','พันตรี')

# %%
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('รตต','ร้อยตำรวจตรี')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ร.ต.ต.','ร้อยตำรวจตรี')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ร.ต.ต','ร้อยตำรวจตรี')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('พ.ท.','พันโท')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('น.ต.','นาวาตรี')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ร.อ.','ร้อยเอก')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ผศ.ดร. ','ผู้ช่วยศาสตราจารย์ ด็อกเตอร์')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('รศ.พญ.','รองศาสตราจารย์ แพทย์หญิง')
tt['ผู้รับผลประโยชน์'] = tt['ผู้รับผลประโยชน์'].str.replace('ด.ท.','ดาบตำรวจโท')

# %%
tt
# Out:
#               ผู้รับผลประโยชน์
# 0          นายปรามาณ มุสิกโปดก
# 1        นายนนทวุฒิ  นวลโคกสูง
# 2              นางกุศล รักญาติ
# 3        นางเรืองศรี  ทรงปัญญา
# 4     นายสกุลโกสินทร์ ศรีรักษา
# ...                        ...
# 5620     นางอาริยา มูลตรีภักดี
# 5621       เด็กชายนนทวัช คงไทย
# 5622         นางนิตยา ดอนอิสวน
# 5623          นางน้ำอ้อม ยาหอม
# 5624     นางสาวศิรัญญา วรพันธ์
#
# [5625 rows x 1 columns]

# %%
set(tt['ผู้รับผลประโยชน์'])
# Out:
# {'นางบัวจันทร์ จันทา  ',
#  'เด็กชายชยพล  วงษ์ละคร ',
#  'นายสุระพงษ์ แขหินตั้ง ',
#  'นางสาววาสนา เทียวไชยภูมิ',
#  'เด็กชายก้องเกียรติไกร ใจเที่ยง',
#  'นางรุ่งทิพย์ ถากันหา ',
#  'นางจำปี  ภูมิดอนชัย',
#  'นายณพฤธ วีระกรพานิช',
#  'นางสุภาภรณ์ สิงหรา',
#  'นางโคศรี กุลศรี',
#  'เด็กชายจันทจักร บุตคโคตร',
#  'เด็กหญิงอมาริยาห์  เชี่ยวธนะกุล',
#  'นางบรรจง  จักราช',
#  'นางธันาย์นันท์ เพียดสิงห์',
#  'นายสุวิทย์ ไข่มุกข์ ',
#  'นายณัฐวุฒิ เบ้าจรรยา ',
#  'นางคำพุ ประสาร',
#  'นายฉันทวัต บุญสุข',
#  'เด็กหญิงชนัฏกาญจน์',
#  'นางสาวกุสุมา  ศักดิ์แสงวิรัต',
#  'นายวธรธนพงศ์  เวียงนนท์',
#  'นางสาวนิภาพร ประสาร',
#  'นางสาวศิรดา  ปัดถาวโร',
#  'นางสุภาสิน ทัพซ้าย',
#  'นายชานนท์  อรรคณิตย์',
#  'นายวีระพล  ศรีกุลวงษ์',
#  'นางเดือนเพ็ญ  ขุนทอง',
#  'นางสาวฐิติมา ทองออน',
#  'นางบุษบัน ศรีเมืองช่าง',
#  'นางคำไส ไกรฤาชา',
#  'พันตรีประสิทธิ์ น้อยชมภู',
#  'เด็กหญิงศริญญา  พิลาทา',
#  'นายสงวน บุญพูน',
#  'นายวชรินันท์  คงทวี',
#  'นายวรินทร์ ยศสุ  ',
#  'นางสาววาสนา ศรีบุญเรือง ',
# ...

# %%
pip install openpyxl

# %%
# บันทึก DataFrame เป็นไฟล์ Excel
tt.to_excel('ทะเบียนกองทุน กฌมข-25042024(python).xlsx', index=False)
#Downlaod ไฟล์

# %% [markdown]
# #อื่น

# %%
df = pd.read_csv('/content/drive/MyDrive/ข้อมูล กองทรัพย์/cleansing.csv', encoding='latin1')
# Out:
# <ipython-input-6-c6e458efe7f8>:1: DtypeWarning: Columns (0,1,3,6,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/ข้อมูล กองทรัพย์/cleansing.csv', encoding='latin1')

# %%
data = pd.read_excel('/content/drive/MyDrive/ข้อมูล กองทรัพย์/cleansing.xlsx') #เรียกใช้ไฟล์ที่ต้องการ และ ตั้งหัวตาราง
data
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                                Unnamed: 0  \
# 0                                         statuslist-อ้อม
# 1                                    ฝึกอบรม ณ ต่างประเทศ
# 2                                         ลาศึกษาในประเทศ
# 3                                    ลาศึกษา ณ ต่างประเทศ
# 4                                    ลาศึกษา ณ ต่างประเทศ
# ...                                                   ...
# 230053                กลับเข้าปฏิบัติราชการหลังจากฝึกอบรม
# 230054                กลับเข้าปฏิบัติราชการหลังจากฝึกอบรม
# 230055                กลับเข้าปฏิบัติราชการหลังจากฝึกอบรม
# 230056  กลับเข้าปฏิบัติราชการหลังจากไปปฏิบัติงานเพื่อเ...
# 230057                                                end
#
#        ดูข้อมูลจาก ประเภทการลาศึกษา ชีต LoVs
# 0                                ประเภทการลา
# ...
